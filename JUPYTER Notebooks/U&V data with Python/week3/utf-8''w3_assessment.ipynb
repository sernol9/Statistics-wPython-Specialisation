# %% [markdown]
# In this assignment we'll ask you to plot multiple variables.
#
# You will use what you find in this assignment to answer the questions in the quiz that follows. It may be useful to keep this notebook side-by-side with this week's quiz on your screen.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 100)

path = "Cartwheeldata.csv"

# %%
# First, you must import the cartwheel data from the path given above
df = pd.read_csv(path)# using pandas, read in the csv data found at the url defined by 'path'

# %%
# Next, look at the 'head' of our DataFrame 'df'. 
df.head()
df.describe()
# Out:
#               ID        Age  GenderGroup  GlassesGroup     Height   Wingspan  \
# count  25.000000  25.000000    25.000000     25.000000  25.000000  25.000000
# mean   13.000000  28.240000     1.520000      0.560000  67.650000  66.260000
# std     7.359801   6.989754     0.509902      0.506623   4.431187   5.492647
# min     1.000000  22.000000     1.000000      0.000000  61.500000  57.500000
# 25%     7.000000  24.000000     1.000000      0.000000  64.000000  62.000000
# 50%    13.000000  26.000000     2.000000      1.000000  68.000000  66.000000
# 75%    19.000000  29.000000     2.000000      1.000000  71.000000  71.000000
# max    25.000000  56.000000     2.000000      1.000000  75.000000  76.000000
#
#        CWDistance  CompleteGroup      Score
# count   25.000000       25.00000  25.000000
# mean    82.480000        0.76000   6.400000
# std     15.058552        0.43589   2.533114
# min     63.000000        0.00000   2.000000
# 25%     70.000000        1.00000   4.000000
# ...

# %% [markdown]
# If you can't remember a function, open a previous notebook or video as a reference, or use your favorite search engine to look for a solution.

# %% [markdown]
# ## Scatter plots

# %% [markdown]
# First, let's looks at two variables that we expect to have a strong relationship, 'Height' and 'Wingspan'.

# %%
# Make a Seaborn scatter plot with x = height and y = wingspan using sns.scatterplot(x, y)
sns.regplot(x="Height", y="Wingspan", data=df, fit_reg=True, scatter_kws={"alpha": 0.2})
g = sns.FacetGrid(df, hue="Gender", height=5, aspect=1.5)
g.map_dataframe(sns.regplot, x="Wingspan", y="Height",fit_reg=True, scatter_kws={"alpha": 0.2})
g.set_axis_labels("Wingspan","Height")
g.add_legend()

# %% [markdown]
# How would you describe the relationship between 'Height' and 'Wingspan'?
# Questions you can ask:
# * Is it linear?
# * Are there outliers?
# * Are their ranges similar or different?
#
# How else could you describe the relationship?

# %% [markdown]
# Now let's look at two variables that we don't yet assume have a strong relationship, 'Wingspan' and 'CWDistance'

# %%
# Make a Seaborn scatter plot with x = wingspan and y = cartwheel distance
sns.regplot(x="CWDistance", y="Wingspan", data=df, fit_reg=True, scatter_kws={"alpha": 0.2})
# Out:
# <AxesSubplot:xlabel='CWDistance', ylabel='Wingspan'>

# %% [markdown]
# How would you describe the relationship between 'Wingspan' and 'CWDistance'?
# * Is it linear?
# * Are there outliers?
# * Are their ranges similar or different?
#
# How else could you describe the relationship?

# %% [markdown]
# Let makes the same plot as above, but now include 'Gender' as the color scheme by including the argument
# ```
# hue=df['Gender']
# ```
# in the Seaborn function

# %%
# Make a Seaborn scatter plot with x = wingspan and y = cartwheel distance, and hue = gender
g = sns.FacetGrid(df, hue="Gender", height=5, aspect=1.5)
g.map_dataframe(sns.regplot, x="CWDistance", y="Wingspan",fit_reg=True, scatter_kws={"alpha": 0.2})
g.set_axis_labels("CWDistance", "Wingspan")
g.add_legend()

# %% [markdown]
# Does does this new information on the plot change your interpretation of the relationship between 'Wingspan' and 'CWDistance'?

# %% [markdown]
# ## Barcharts
# Now lets plot barplots of 'Glasses'

# %%
# Make a Seaborn barplot with x = glasses and y = cartwheel distance
sns.barplot(x="Glasses", y="CWDistance", data=df)
# Out:
# <AxesSubplot:xlabel='Glasses', ylabel='CWDistance'>

# %% [markdown]
# What can you say about the relationship of 'Glasses' and 'CWDistance'?

# %%
# Make the same Seaborn boxplot as above, but include gender for the hue argument
sns.barplot(x="Glasses", y="CWDistance", hue="Gender", data=df)
# Out:
# <AxesSubplot:xlabel='Glasses', ylabel='CWDistance'>

# %% [markdown]
# How does this new plot change your interpretation about the relationship of 'Glasses' and 'CWDistance'?
