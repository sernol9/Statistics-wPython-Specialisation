# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Este es un programa de prueba en jupyter notebook

# %%
nano = input ("Dime tu nombre:")
print (nano)
# Out:
# Dime tu nombre:Yo
# Yo

# %% [markdown]
# # ![8590077_web1_dragonboats_052217_rb_015.jpg](attachment:8590077_web1_dragonboats_052217_rb_015.jpg)
